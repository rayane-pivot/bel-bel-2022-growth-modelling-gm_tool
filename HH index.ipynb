# %%
"""
HH index in Houshold penetration index
"""
# Out:
# '\nHH index in Houshold penetration index\n'

# %%
import pandas as pd

# %%
df = pd.read_excel('data/Growth Modelling - USA - Consumer Panel -US HH penetration GM.xlsx', header=7)

# %%
df = df.rename(columns={'Unnamed: 0':'Product', 'Unnamed: 1':'Brand'})

# %%
df.columns.values.indexof('')
# Out:
#                            Product                 Brand  \
# 0                  CHEESE & COMBOS    Total All Products
# 1                  CHEESE & COMBOS               BOURSIN
# 2                  CHEESE & COMBOS               BABYBEL
# 3                  CHEESE & COMBOS      THE LAUGHING COW
# 4                  CHEESE & COMBOS              KAUKAUNA
# 5                  CHEESE & COMBOS                MERKTS
# 6                  CHEESE & COMBOS                PRICES
# 7                           COMBOS    Total All Products
# 8                           COMBOS               BABYBEL
# 9                           COMBOS      THE LAUGHING COW
# 10                    CREAM CHEESE    Total All Products
# 11                 CLASSIC SPREADS    Total All Products
# 12                 CLASSIC SPREADS              KAUKAUNA
# 13                 CLASSIC SPREADS                MERKTS
# 14              ENTERTAINING TRAYS    Total All Products
# ...
